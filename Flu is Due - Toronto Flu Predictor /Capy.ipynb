# %% [markdown]
# Code that was being used:

# %%
import pandas as pd 

templated = pd.read_csv('templated.csv')
templated.head()
# Out:
#    Unnamed: 0  begin_date institution  type causative1  setting    end_date  \
# 0           0  2016-01-01          nl   0.0    unknown      6.0  2018-12-11
# 1           1  2016-01-02          nl   0.0    unknown      6.0  2018-12-11
# 2           2  2016-01-03          nl   0.0    unknown      6.0  2018-12-11
# 3           3  2016-01-04          nl   0.0    unknown      6.0  2018-12-11
# 4           4  2016-01-05          nl   0.0    unknown      6.0  2018-12-11
#
#    latitude  longitude    Month  Year    _dt_diff
# 0     43.65     -79.38  January  2016  2016-01-01
# 1     43.65     -79.38  January  2016  2016-01-02
# 2     43.65     -79.38  January  2016  2016-01-03
# 3     43.65     -79.38  January  2016  2016-01-04
# 4     43.65     -79.38  January  2016  2016-01-05

# %%
i=templated.institution.unique()
c=
# Out:
# array(['nl', 'west park long term care',
#        'sunnybrook health sciences centre', 'midland gardens community',
#        'salvation army health centre', "st john's rehabilitation centre",
#        "St. Joseph's Health Centre ", 'castleview wychwood',
#        'wexford residence', 'belmont house retirment home',
#        'Providence Healthcare ', "o'neill centre",
#        'tendercare living centre', 'chartwell gibson long term care home',
#        'camh', 'cummer lodge', 'North York General Hospital ',
#        'better living thompson house', 'rockcliffe',
#        'yee hong centre for geriatric care', 'Kensington Gardens ',
#        'scarborough and rouge hospital', 'Michael Garron Hospital '],
#       dtype=object)

# %%
quicktuple=set(zip(templated.institution.unique(), templated.causative1.unique()))
print(quicktuple)
# Out:
# {('yee hong centre for geriatric care', 'Influenza A (H3), Parainfluenza type 2'), ('Kensington Gardens ', 'Pending'), ('west park long term care', 'Coronavirus'), ('North York General Hospital ', 'Parainfluenza type 4'), ('camh', 'Parainfluenza type 3'), ('cummer lodge', 'Rhinovirus'), ("o'neill centre", 'Unable to identify'), ('better living thompson house', 'Adenovirus'), ('tendercare living centre', 'Streptococcus pyogenes'), ('Providence Healthcare ', 'Metapneumovirus'), ('chartwell gibson long term care home', 'Parainfluenza type 1'), ("St. Joseph's Health Centre ", 'Influenza A (Not subtyped)'), ('midland gardens community', 'Respiratory syncytial virus'), ('sunnybrook health sciences centre', 'Enterovirus/Rhinovirus'), ('nl', 'unknown'), ('rockcliffe', 'Parainfluenza type 2'), ('belmont house retirment home', 'Influenza B'), ('wexford residence', 'Influenza A (H3)'), ("st john's rehabilitation centre", ' Respiratory syncytial virus'), ('castleview wychwood', 'Influenza A ((H1
# ...

# %%
templated['institution']
# Out:
# 0                                         nl
# 1                                         nl
# 2                                         nl
# 3                                         nl
# 4                                         nl
# 5                                         nl
# 6                                         nl
# 7                   west park long term care
# 8                                         nl
# 9                                         nl
# 10         sunnybrook health sciences centre
# 11                 midland gardens community
# 12                                        nl
# 13                                        nl
# 14                                        nl
# 15              salvation army health centre
# 16                                        nl
# 17                                        nl
# 18                                        nl
# 19         sunnybrook health sciences centre
# 20           st john's rehabilitation centre
# ...

# %%
templated.institution.unique()
# Out:
# array(['nl', 'west park long term care',
#        'sunnybrook health sciences centre', 'midland gardens community',
#        'salvation army health centre', "st john's rehabilitation centre",
#        "St. Joseph's Health Centre ", 'castleview wychwood',
#        'wexford residence', 'belmont house retirment home',
#        'Providence Healthcare ', "o'neill centre",
#        'tendercare living centre', 'chartwell gibson long term care home',
#        'camh', 'cummer lodge', 'North York General Hospital ',
#        'better living thompson house', 'rockcliffe',
#        'yee hong centre for geriatric care', 'Kensington Gardens ',
#        'scarborough and rouge hospital', 'Michael Garron Hospital '],
#       dtype=object)

# %%
rename infection to sunnybrook, 
add corona virus to another hospital
left join all

# %%
sunny = templated[
    (templated['institution'] == 'sunnybrook health sciences centre')
]

corona = sunny[['begin_date', 'end_date']]
corona['sunnybrook'] = 1
corona

coronaz = sunny[['begin_date', 'end_date']]
coronaz['sunnybrook'] = 1
coronaz
# Out:
# /Applications/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Applications/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
#       begin_date    end_date  sunnybrook
# 10    2016-01-11  2016-01-18           1
# 19    2016-01-19  2016-01-27           1
# 51    2016-02-18  2016-03-05           1
# 58    2016-02-24  2016-03-06           1
# ...

# %%
# def alla_diz():

#     institutions = templated.institution.unique()
#     tempinst=templated['institution']
#     whatevs= templated.institution.unique()

#     for i,ii in zip(tempinst,institutions):
#          whatevs = templated[
#         (i == institutions)]
        
#     newthang = whatevs[['begin_date', 'end_date']]
#     newthang['infection'] = 1

#     newestthang = pd.concat([pd.DataFrame({
#             'start': pd.date_range(row.begin_date, row.end_date, freq='D'),
#             'infection': row.infection
#             })
#             for i, row in newthang.iterrows()], 
#     ignore_index=True)

# alla_diz()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-ab2166ab54c3> in <module>()
#      20     ignore_index=True)
#      21
# ---> 22 alla_diz()
#
# <ipython-input-51-ab2166ab54c3> in alla_diz()
#       8     for i,ii in zip(tempinst,institutions):
#       9          whatevs = templated[
# ---> 10         (i == institutions)]
#      11
#      12     newthang = whatevs[['begin_date', 'end_date']]
#
# /Applications/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2680         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2681             # either boolean or fancy integer index
# -> 2682             return self._getitem_array(key)
#    2683         elif isinstance(key, DataFrame):
#    2684             return self._getitem_frame(key)
#
# ...

# %% [markdown]
# #### def date_expander(dataframe: pd.DataFrame,
#                   begin_date: str,
#                   end_date: str,
#                   time_unit: str,
#                   new_colname: str,
#                   end_inclusive: bool)

# %%
sunny_corona = pd.concat([
    pd.DataFrame({
        'start': pd.date_range(row.begin_date, row.end_date, freq='D'),
        'infection': row.infection
    })
    for i, row in corona.iterrows()], 
    ignore_index=True)

# %%
calendar = pd.DataFrame({'start': pd.date_range(start='2016-01-01', end='2018-11-30')})

# %%
calendar.head()
# Out:
#        start
# 0 2016-01-01
# 1 2016-01-02
# 2 2016-01-03
# 3 2016-01-04
# 4 2016-01-05

# %%
sunny_corona.head()
# Out:
#        start  infection
# 0 2016-01-19          1
# 1 2016-01-20          1
# 2 2016-01-21          1
# 3 2016-01-22          1
# 4 2016-01-23          1

# %%
s1 = pd.merge(calendar, sunny_corona, how='left', on=['start'])

# %%
s1 = s1.fillna(0)

# %%
s1
# Out:
#           start  infection
# 0    2016-01-01        0.0
# 1    2016-01-02        0.0
# 2    2016-01-03        0.0
# 3    2016-01-04        0.0
# 4    2016-01-05        0.0
# 5    2016-01-06        0.0
# 6    2016-01-07        0.0
# 7    2016-01-08        0.0
# 8    2016-01-09        0.0
# 9    2016-01-10        0.0
# 10   2016-01-11        0.0
# 11   2016-01-12        0.0
# 12   2016-01-13        0.0
# 13   2016-01-14        0.0
# 14   2016-01-15        0.0
# 15   2016-01-16        0.0
# 16   2016-01-17        0.0
# 17   2016-01-18        0.0
# 18   2016-01-19        1.0
# 19   2016-01-20        1.0
# 20   2016-01-21        1.0
# 21   2016-01-22        1.0
# 22   2016-01-23        1.0
# 23   2016-01-24        1.0
# 24   2016-01-25        1.0
# 25   2016-01-26        1.0
# 26   2016-01-27        1.0
# 27   2016-01-28        0.0
# 28   2016-01-29        0.0
# 29   2016-01-30        0.0
# ...         ...        ...
# 1059 2018-11-01        0.0
# 1060 2018-11-02        0.0
# ...

# %%
sunny = templated[
    (templated['institution'] == 'sunnybrook health sciences centre')]

corona = sunny[['begin_date', 'end_date']]
corona['infection'] = 1
corona

sunny_corona = pd.concat([
    pd.DataFrame({
        'start': pd.date_range(row.begin_date, row.end_date, freq='D'),
        'sunnybrook': row.infection
    })
    for i, row in corona.iterrows()], 
    ignore_index=True)

sunny_corona
# Out:
# /Applications/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#          start  sunnybrook
# 0   2016-01-11           1
# 1   2016-01-12           1
# 2   2016-01-13           1
# 3   2016-01-14           1
# 4   2016-01-15           1
# 5   2016-01-16           1
# 6   2016-01-17           1
# 7   2016-01-18           1
# 8   2016-01-19           1
# 9   2016-01-20           1
# 10  2016-01-21           1
# 11  2016-01-22           1
# 12  2016-01-23           1
# 13  2016-01-24           1
# 14  2016-01-25           1
# 15  2016-01-26           1
# 16  2016-01-27           1
# 17  2016-02-18           1
# 18  2016-02-19           1
# 19  2016-02-20           1
# ...

# %%
sunny = templated[
    (templated['institution'] == 'sunnybrook health sciences centre') & 
    (templated['causative1'] == 'Coronavirus')
]

corona = sunny[['begin_date', 'end_date']]
corona['infection'] = 1
corona

sunny_corona = pd.concat([
    pd.DataFrame({
        'start': pd.date_range(row.begin_date, row.end_date, freq='D'),
        'infection': row.infection
    })
    for i, row in corona.iterrows()], 
    ignore_index=True)
# Out:
# /Applications/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
